# %%
# %load_ext sql

# %%
# %sql sqlite:///publications.db

# %% [markdown]
# # Challenge 1

# %% [markdown]
# ## Step 1

# %%
# %%sql
# select  ta.title_id Title_ID,
#         ta.au_id Author_ID,
#         t.price*s.qty*t.royalty/100*ta.royaltyper/100 SALES_ROYALTY
# from sales s
# left join titleauthor ta
# on s.title_id=ta.title_id
# left join authors a
# on a.au_id=ta.au_id
# left join titles t
# on t.title_id=s.title_id
# Out:
#  * sqlite:///publications.db
# Done.
# [('BU1032', '213-46-8915', 3.9979999999999993),
#  ('BU1032', '409-56-7008', 5.996999999999999),
#  ('PS2091', '899-46-2035', 1.9709999999999996),
#  ('PS2091', '998-72-3567', 1.9709999999999996),
#  ('PC8888', '427-17-2319', 50),
#  ('PC8888', '846-92-7186', 50),
#  ('PS2091', '899-46-2035', 49.275),
#  ('PS2091', '998-72-3567', 49.275),
#  ('PS2091', '899-46-2035', 6.57),
#  ('PS2091', '998-72-3567', 6.57),
#  ('TC3218', '807-91-6654', 83.8),
#  ('TC4203', '648-92-1872', 33.46),
#  ('TC7777', '267-41-2394', 8.994),
#  ('TC7777', '472-27-2349', 8.994),
#  ('TC7777', '672-71-3249', 11.992),
#  ('PS2091', '899-46-2035', 13.14),
#  ('PS2091', '998-72-3567', 13.14),
#  ('MC3021', '722-51-5454', 13.455),
#  ('MC3021', '899-46-2035', 4.485),
#  ('PS1372', '724-80-9391', 10.795),
#  ('PS1372', '756-30-7391', 32.385),
#  ('PS2106', '998-72-3567', 17),
#  ('PS3333', '172-32-1176', 29.984999999999996),
#  ('PS7777', '486-29-1786', 19.975),
# ...

# %% [markdown]
# ## Step 2

# %%
# %%sql
# with royals as(
# select  ta.title_id Title_ID,
#         ta.au_id Author_ID,
#         t.price*s.qty*t.royalty/100*ta.royaltyper/100 SALES_ROYALTY
# from sales s
# left join titleauthor ta
# on s.title_id=ta.title_id
# left join authors a
# on a.au_id=ta.au_id
# left join titles t
# on t.title_id=s.title_id)
# select Title_ID,Author_ID, sum(SALES_ROYALTY) Sum_Sales from royals
# Group by Title_ID, Author_ID
# order by Title_ID desc
# Out:
#  * sqlite:///publications.db
# Done.
# [('TC7777', '267-41-2394', 8.994),
#  ('TC7777', '472-27-2349', 8.994),
#  ('TC7777', '672-71-3249', 11.992),
#  ('TC4203', '648-92-1872', 33.46),
#  ('TC3218', '807-91-6654', 83.8),
#  ('PS7777', '486-29-1786', 19.975),
#  ('PS3333', '172-32-1176', 29.984999999999996),
#  ('PS2106', '998-72-3567', 17),
#  ('PS2091', '899-46-2035', 70.95599999999999),
#  ('PS2091', '998-72-3567', 70.95599999999999),
#  ('PS1372', '724-80-9391', 10.795),
#  ('PS1372', '756-30-7391', 32.385),
#  ('PC8888', '427-17-2319', 50),
#  ('PC8888', '846-92-7186', 50),
#  ('PC1035', '238-95-7766', 110.16),
#  ('MC3021', '722-51-5454', 21.528),
#  ('MC3021', '899-46-2035', 7.176),
#  ('MC2222', '712-45-1867', 23.987999999999996),
#  ('BU7832', '274-80-9391', 29.984999999999996),
#  ('BU2075', '213-46-8915', 25.116000000000003),
#  ('BU1111', '267-41-2394', 11.95),
#  ('BU1111', '724-80-9391', 17.925),
#  ('BU1032', '213-46-8915', 11.993999999999998),
# ...

# %% [markdown]
# ## Step 3

# %%
# %%sql
# with royals2 as (with royals as(
#     select  ta.title_id Title_ID,
#             ta.au_id Author_ID,
#             t.price*s.qty*t.royalty/100*ta.royaltyper/100 SALES_ROYALTY
#     from sales s
#     left join titleauthor ta
#     on s.title_id=ta.title_id
#     left join authors a
#     on a.au_id=ta.au_id
#     left join titles t
#     on t.title_id=s.title_id)
#     select Title_ID,Author_ID, sum(SALES_ROYALTY) as aggroyal from royals
#     Group by Title_ID, Author_ID)
# select ry2.Author_ID, ry2.aggroyal+t.advance Profit
# from royals2 ry2
# join titles t
# on ry2.title_id=t.title_id
# GROUP BY ry2.Author_ID
# order by Profit desc
# Out:
#  * sqlite:///publications.db
# Done.
# [('722-51-5454', 15021.528),
#  ('899-46-2035', 15007.176),
#  ('846-92-7186', 8050),
#  ('427-17-2319', 8050),
#  ('672-71-3249', 8011.992),
#  ('472-27-2349', 8008.994),
#  ('238-95-7766', 7110.16),
#  ('807-91-6654', 7083.8),
#  ('756-30-7391', 7032.385),
#  ('274-80-9391', 5029.985),
#  ('409-56-7008', 5017.991),
#  ('724-80-9391', 5017.925),
#  ('213-46-8915', 5011.994),
#  ('267-41-2394', 5011.95),
#  ('648-92-1872', 4033.46),
#  ('486-29-1786', 4019.975),
#  ('998-72-3567', 2345.956),
#  ('172-32-1176', 2029.985),
#  ('712-45-1867', 23.987999999999996)]

# %% [markdown]
# # Challenge 2

# %%
# %%sql
# CREATE TABLE 'most_profiting_authors' (
#     'Author_id' varchar(40) NOT NULL PRIMARY KEY,
#     'Profits' real DEAFAULT NULL
# )
# Out:
#  * sqlite:///publications.db
# Done.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-88-bb9655e3d936> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE TABLE 'most_profiting_authors' (\n    'Author_id' varchar(40) NOT NULL PRIMARY KEY,\n    'Profits' real DEAFAULT NULL\n)\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
# ...

# %%
# %%sql
# insert into most_profiting_authors
# with royals2 as (with royals as(
#     select  ta.title_id Title_ID,
#             ta.au_id Author_ID,
#             t.price*s.qty*t.royalty/100*ta.royaltyper/100 SALES_ROYALTY
#     from sales s
#     left join titleauthor ta
#     on s.title_id=ta.title_id
#     left join authors a
#     on a.au_id=ta.au_id
#     left join titles t
#     on t.title_id=s.title_id)
#     select Title_ID,Author_ID, sum(SALES_ROYALTY) as aggroyal from royals
#     Group by Title_ID, Author_ID)
# select ry2.Author_ID, ry2.aggroyal+t.advance Profit
# from royals2 ry2
# join titles t
# on ry2.title_id=t.title_id
# GROUP BY ry2.Author_ID
# order by Profit desc
# Out:
#  * sqlite:///publications.db
# 19 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-89-6ef2bfd26d87> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'insert into most_profiting_authors\nwith royals2 as (with royals as(\n    select  ta.title_id Title_ID,\n            ta.au_id Author_ID,\n            t.price*s.qty*t.royalty/100*ta.royaltyper/100 SALES_ROYALTY\n    from sales s\n    left join titleauthor ta\n    on s.title_id=ta.title_id\n    left join authors a\n    on a.au_id=ta.au_id\n    left join titles t\n    on t.title_id=s.title_id)\n    select Title_ID,Author_ID, sum(SALES_ROYALTY) as aggroyal from royals \n    Group by Title_ID, Author_ID)\nselect ry2.Author_ID, ry2.aggroyal+t.advance Profit\nfrom royals2 ry2\njoin titles t\non ry2.title_id=t.title_id\nGROUP BY ry2.Author_ID\norder by Profit desc\n')
#
# ...

# %%
# %%sql
# select * from
# most_profiting_authors
# Out:
#  * sqlite:///publications.db
# Done.
# [('722-51-5454', 15021.528),
#  ('899-46-2035', 15007.176),
#  ('846-92-7186', 8050.0),
#  ('427-17-2319', 8050.0),
#  ('672-71-3249', 8011.992),
#  ('472-27-2349', 8008.994),
#  ('238-95-7766', 7110.16),
#  ('807-91-6654', 7083.8),
#  ('756-30-7391', 7032.385),
#  ('274-80-9391', 5029.985),
#  ('409-56-7008', 5017.991),
#  ('724-80-9391', 5017.925),
#  ('213-46-8915', 5011.994),
#  ('267-41-2394', 5011.95),
#  ('648-92-1872', 4033.46),
#  ('486-29-1786', 4019.975),
#  ('998-72-3567', 2345.956),
#  ('172-32-1176', 2029.985),
#  ('712-45-1867', 23.987999999999996)]
